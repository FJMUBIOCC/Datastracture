# %%
from pyecharts.globals import CurrentConfig, NotebookType
from pyecharts.globals import CurrentConfig, OnlineHostType
CurrentConfig.NOTEBOOK_TYPE = NotebookType.JUPYTER_LAB
CurrentConfig.ONLINE_HOST = OnlineHostType.NOTEBOOK_HOST
#from example.commons import Faker
from pyecharts import options as opts
from pyecharts.charts import Bar,Page
from pyecharts.globals import ChartType, SymbolType
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
OnlineHostType.NOTEBOOK_HOST
# Out:
# 'http://localhost:8888/nbextensions/assets/'

# %% [markdown]
# ## 直接从图片生成热图

# %%
from IPython.core.display import Image as img

# %%
heat = img("热图.JPG")
heat

# %%
from PIL import Image
from pylab import *
# 读取图像到数组中
im = Image.open("热图.JPG")
data = array(im)
# 绘制图像
imshow(data)
# 一些点
x = [100,100,400,400]
y = [200,300,200,100]
# 添加标题，显示绘制的图像
title('Plotting: "color"')
show()

# %%
class heat:
    width = 0
    height = 0
    def __init__(img):
        from PIL import Image
        _im = Image.open(img)
        _colors = _im.getdata() 
    def read(self):
        self.width = _im.size[0]
        self.height = im.size[1]
        
    

im.size
# Out:
# (430, 267)

# %%
imshow(color_mask)

# %%
y = im.size[1]/16
x = im.size[0]/25
d = (x+y)/2
c = im.crop((400-400/6,0,400,300/4))
t = [i for i in c.getdata()]
d,x,y
# Out:
# (16.94375, 17.2, 16.6875)

# %%
data = array(im)
color_set = []
for i in range(len(data)):
    for j in range(len(data[i])):
        for k in range(len(data[i][j])):
            data[i][j][k] = data[i][j][k]//32*32
        color_set.append(data[i][j])

        

        
#color_mask = set(color_set)
"""
for i in set(color_mask):
    #print (i,color_mask.count(i))
    if color_mask.count(i)>9:
        color_set.append(i)
#for color in color_mask:[]
#    print(color_set.index(color))
"""
imshow(data)

# %%
x = 0
y = 0
i = 1
j = 1
equal_mask = []
for i in range(len(data)-1):
    ls = []
    for j in range(len(data[i])):
        ls.append(sum([i**2 for i in (data[i+1][j]-data[i][j])]))
    equal_mask.append(ls)
equal_mask = np.array(equal_mask)

# %%
imshow(equal_mask)

# %%
# ?np.array
# Out:
# Docstring:
# array(object, dtype=None, copy=True, order='K', subok=False, ndmin=0)
#
# Create an array.
#
# Parameters
# ----------
# object : array_like
#     An array, any object exposing the array interface, an object whose
#     __array__ method returns an array, or any (nested) sequence.
# dtype : data-type, optional
#     The desired data-type for the array.  If not given, then the type will
#     be determined as the minimum type required to hold the objects in the
#     sequence.  This argument can only be used to 'upcast' the array.  For
#     downcasting, use the .astype(t) method.
# copy : bool, optional
#     If true (default), then the object is copied.  Otherwise, a copy will
#     only be made if __array__ returns a copy, if obj is a nested sequence,
#     or if a copy is needed to satisfy any of the other requirements
#     (`dtype`, `order`, etc.).
# order : {'K', 'A', 'C', 'F'}, optional
#     Specify the memory layout of the array. If object is not an array, the
# ...

# %%
color1 = c

# %%
# %matplotlib inline
t = [i for i in color1.getdata()]
t.sort()
crs = []
for i in range(6):
    for j in range(4):
        c = color1.crop((i*x,j*y,x*(i+1),y*(j+1)))
        t = [i for i in c.getdata()]
        t.sort()
        col = t[int(len(t)/2)]
        if i ==5 and j==0:
            col = t[int(len(t)*1/2.2)]
        d  = list(col)
        d.append(255)
        d  = [i/255 for i in d]
        d  = tuple(d)
        crs.append(d)
        plt.fill_between([i*x,x*(i+1)], [300-j*y,300-j*y],[300-(j+1)*y,300-y*(j+1)],facecolor=d)
